# %% [markdown]
# <a href="https://colab.research.google.com/github/jmbanquez13-coder/Nootbooks_Agro_2026_1/blob/main/Rendimiento_Extracci%C3%B3n_Aceite_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Control de Rendimiento en Extracción de Aceite**
#
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento:**
#
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el **peso total de los racimos de fruta fresca (RFF)** procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos:**
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float). (pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float). (lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L. (r)
#
# $$Pa = lt * 0.92$$
#
# $$r =(pa/pr) * 100$$
#
# **Prueba del programa:**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRADA: Solicitar el nombre del lote de producción (Tipo string).
# Solicitar el peso de los racimos en kg (Tipo float). (pr)
# Solicitar los litros de aceite obtenidos (Tipo float). (lt)
nombre = input("Ingrese el nombre del lote: ")
pr = float(input("Ingrese el peso de los racimos en kg: "))
lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))

# PROCESO: Calcular peso del aceite (pa) y el rendimiento (r)
pa = lt * 0.92
r = (pa/pr) * 100

#SALIDA: Informar el rendimiento del lote
print("El rendimiento del lote", nombre, "es del", r, "%")
# Out:
# Ingrese el nombre del lote: Juan tu Macho
# Ingrese el peso de los racimos en kg: 1000
# Ingrese la cantidad de aceite crudo obtenido en litros: 200
# El rendimiento del lote Juan tu Macho es del 18.4 %

# %% [markdown]
# Aquí te presento la explicación de cada línea de código del problema 'Control de Rendimiento en Extracción de Aceite':
#
# ```python
# # ENTRADA: Solicitar el nombre del lote de producción (Tipo string).
# # Solicitar el peso de los racimos en kg (Tipo float). (pr)
# # Solicitar los litros de aceite obtenidos (Tipo float). (lt)
# ```
# Estas líneas son comentarios (`#`), utilizadas para documentar el código. Indican qué tipo de datos se solicitan al usuario: el nombre del lote (string), el peso de los racimos en kg (float) y los litros de aceite obtenidos (float).
#
# ```python
# nombre = input("Ingrese el nombre del lote: ")
# ```
# Esta línea de código utiliza la función `input()` para solicitar al usuario que "Ingrese el nombre del lote:". La entrada del usuario, que es un texto (string), se almacena en la variable `nombre`.
#
# ```python
# pr = float(input("Ingrese el peso de los racimos en kg: "))
# ```
# Aquí, `input()` solicita al usuario que "Ingrese el peso de los racimos en kg:". La entrada del usuario se convierte a un número decimal (`float`) usando `float()` y se guarda en la variable `pr` (peso de los racimos).
#
# ```python
# lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))
# ```
# Similar a la línea anterior, `input()` pide al usuario "Ingrese la cantidad de aceite crudo obtenido en litros:". Esta entrada también se convierte a un número decimal (`float`) y se almacena en la variable `lt` (litros de aceite).
#
# ```python
# # PROCESO: Calcular peso del aceite (pa) y el rendimiento (r)
# ```
# Este es otro comentario que indica que las siguientes líneas de código se encargarán de realizar los cálculos necesarios.
#
# ```python
# pa = lt * 0.92
# ```
# Esta línea calcula el peso del aceite (`pa`). Multiplica los litros de aceite obtenidos (`lt`) por la densidad aproximada del aceite (0.92 kg/L). El resultado se guarda en `pa`.
#
# ```python
# r = (pa/pr) * 100
# ```
# Esta línea calcula el Índice de Rendimiento de Extracción (`r`). Divide el peso del aceite (`pa`) por el peso de los racimos procesados (`pr`), y luego multiplica el resultado por 100 para obtener un porcentaje. El valor se guarda en la variable `r`.
#
# ```python
# #SALIDA: Informar el rendimiento del lote
# ```
# Este comentario señala que la siguiente línea se encargará de mostrar los resultados al usuario.
#
# ```python
# print("El rendimiento del lote", nombre, "es del", r, "%")
# ```
# Finalmente, la función `print()` muestra el resultado. Concatena varias cadenas de texto y los valores de las variables `nombre` y `r` para formar un mensaje legible que informa al usuario sobre el rendimiento del lote.
